# %% [markdown]
# #### 1. Data Types
#
# **Task:**
#
# ---
# Store your name (string), age (integer), height (float), and student status (boolean). Print each one on a new line.
#
# Hint: Use variables and the `print()` function.
#
# **Advanced:**
#
# ---
# Print a single formatted sentence like:
# "Hi, my name is Alice. I am 23 years old, 1.65 meters tall, and it is True that I am a student."
#
# Hint: Use `f-strings` or `.format()` for better practice.

# %%
# Task 1:
name, age, height, student_status = "Davit", 30, 172.5, False
print(f"name: {name} | type:{type(name).__name__}")
print(f"age: {age} | type:{type(age).__name__}")
print(f"height: {height} | type:{type(height).__name__}")
print(f"student_status: {student_status} | type:{type(student_status).__name__}")

# Advanced:
print(f"Hi, my name is {name}. I am {age} years old, {height/100}, meters tall, and it is {student_status} that I am a student.")
# Out:
# name: Davit | type:str
# age 30 | type:int
# height 172.5 | type:float
# student_status False | type:bool
# Hi, my name is Davit. I am 30 years old, 1.725, meters tall, and it is False that I am a student.

# %% [markdown]
# #### 2. Type Conversion
#
# **Task:**
#
# ---
# Ask the user for their birth year (as a string). Convert it to an integer and calculate their age.
#
# Hint: Use `input()`, `int()`, and basic math.
#
# **Advanced:**
#
# ---
# Check if birth year is a reasonable year (between 1900 and 2025). If the year is not valid, print an error.
#
# Hint: Use `if` to validate after converting.

# %%
# Advanced 2:
birth_year = int(input("Enter your birth year: ").strip())
if 1990 <= birth_year <= 2025:
    age = 2025 - birth_year
    print(f"Your age is {age}")
else:
    print("Invalid birth year. Please enter a year between 1990 and 2025")
# Out:
# Enter your birth year:  1998
# Your age is 27

# %% [markdown]
# #### 3. Conditional Statements (Control Flow)
#
# **Task:**
#
# ---
# Ask for a number. Print whether it is positive, negative, or zero.
#
# Hint: Use `if`, `elif`, and `else`.
#
# **Advanced:**
#
# ---
# Tell if the input number is even or odd.
#
# Hint: Use `% 2 == 0` to check evenness.

# %%
# Task 3:
number = int(input("Enter a number: "))
if number > 0:
    print("Posotive")
elif number < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:  0
# Zero

# %%
number = int(input("Enter a number: "))
if number%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  5
# Odd

# %% [markdown]
# #### 4. If-Else Chains (Grades)
#
# **Task:**
#
# ---
# Ask the user for a grade (0–100). Print "A", "B", "C", "D", or "F".
#
# Hint: Multiple `if-elif-else` statements; use comparison operators.

# %%
# Solution 4:
score = float(input("Enter your score (0-100): "))
if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")
# Out:
# Enter your score (0-100):  100
# A

# %% [markdown]
# #### 5. For Loop (Counting)
#
# **Task:**
#
# ---
# Print squares of the numbers from 1 to 10 using a for loop.
#
# Hint: Use `range(start, stop)`.
#
# **Advanced:**
#
# ---
# Print numbers from 1 to 20, but:
#
# - Print "Fizz" instead of multiples of 3.
# - Print "Buzz" instead of multiples of 5.
# - Print "FizzBuzz" for multiples of both.
#
# Hint: Use `if`, `elif`, `else`.

# %%
# Task 5
print("Solution of Task:")
for i in range(1, 11):
    i = (i**2)
    print(f"{i}")
print("Solution for Advanced")
for j in range(1, 21):
    if j % 3 % 5 == 0:
        Z = "FizzBuzz"
    elif j % 3 == 0:
        Z = "Fizz"
    elif j % 5 == 0:
        Z = "Buzz"
    else:
        Z = str(j)
    print(Z)
# Out:
# Solution of Task:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# Solution for Advanced
# 1
# 2
# FizzBuzz
# 4
# Buzz
# FizzBuzz
# 7
# 8
# FizzBuzz
# Buzz
# 11
# FizzBuzz
# 13
# 14
# FizzBuzz
# 16
# 17
# FizzBuzz
# 19
# Buzz

# %% [markdown]
# #### 6. While Loop Password
#
# **Task:**
#
# ---
# Ask the user for a password. Repeat until they type `"python123"`.
#
# Hint: Use a `while` loop and compare input to the correct password.

# %%
# Solution 6:
password = ("paython123")
user_input = input("Enter passwor: ")
while user_input != pasword:
    user_input = input("Your password is incorrect. Try again: ")
else:
    print("Accsess granted!")
# Out:
# Enter passwor:  214
# Your password is incorrect. Try again:  6789
# Your password is incorrect. Try again:  paython123
# Accsess granted!

# %% [markdown]
# #### 7. Lists and Indexing
#
# **Task:**
#
# ---
# Create a list of 5 favorite foods. Print the first and last items.
#
# Hint: Lists use `[ ]` brackets; index `0` is the first element, `-1` is the last.
#
# **Advanced:**
#
# ---
# Then:
# * Add a book the user suggests.
# * Remove a book if the user dislikes one.
# * Check if a specific book ("Rich Dad Poor Dad") is in your list.
#
# Hint: Use `append()`, `remove()`, and `in`.

# %%
# Solution 7:
foods = ["grilled lamb", "trout fish", "omelet", "dolma", "grace salad"]
print(foods[0])
print(foods[-1])
new_food = input("What food do you sugges: ")
if new_food not in foods:
    foods.append(new_food)
else:
    foods
disliked_food = input("Which food do you dislike? ")
if disliked_food in foods:
    foods.remove(disliked_food)
else:
    foods
if "barbiquie" in foods:
    print("barbique is in your list")
else:
    print("barbique is not in your list")
print("final list:", foods)
# Out:
# grilled lamb
# grace salad
# What food do you sugges:  barbique
# Which food do you dislike?  omlet
# barbique is not in your list
# final list: ['grilled lamb', 'trout fish', 'omelet', 'dolma', 'grace salad', 'barbique']

# %% [markdown]
# #### 8. Tuples (Immutable Containers)
#
# **Task:**
#
# ---
# Create a tuple of 3 cities you want to visit. Try changing one element and observe the error.
#
# Hint: Tuples are created with `( )` and are immutable (can't change items).
#
# **Advanced:**
#
# ---
# Then
# - Convert it into a list.
# - Add a fourth city.
# - Then convert it back to a tuple.
#
# Hint: Use `list()` and `tuple()` functions.

# %%
# task 8:
cities = ("Yerevan", "Gymri", "Vamadzor")
# cities[1] = "Moscow"
cities1 = list(cities)
cities1.append("Moscow")
cities = tuple(cities1)
print(cities)
# Out:
# ('Yerevan', 'Gymri', 'Vamadzor', 'Moscow')

# %% [markdown]
# #### 9. Dictionaries with Input
#
# **Task:**
#
# ---
# Create a dictionary where 3 countries are keys and their capitals are values. Print them.
#
# Hint: Dictionaries use `{key: value}` syntax.

# %%
# Solution 9:
capitals = {"Armenia": "Yerevan", "Russia": "Moscow", "Frnace": "Paris"}
for country, capital in capitals.items():
    print(f"The capital of {country} is {capital}.")
# Out:
# The capital of Armenia is Yerevan.
# The capital of Russia is Moscow.
# The capital of Frnace is Paris.

# %% [markdown]
# #### 10. Sets
#
# **Task:**
#
# ---
# Create two sets: favorite fruits and disliked fruits. Find the difference (favorite but not disliked).
#
# Hint: Use `set()` and `set.difference()` or `-` operator.

# %%
# Task 10:
favorite_fruites = {"apricot", "cocos", "pomegranade","mango", "kiwi"}
disliked_fruites = {"unripe mango", "kiwi", "pamelo"}
only_favorites = favorite_fruites.difference(disliked_fruites)
print("Fruites you like but don't dislike:", only_favorites)
# Out:
# Fruites you like but don't dislike: {'apricot', 'mango', 'cocos', 'pomegranade'}
