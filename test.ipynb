# %%
import numpy as np
np. arange (10, 20, 4)
# Out:
# array([10, 14, 18])

# %%
numb = np.array ([26, 14, 5, 77, 399])
# numb[numb % 2 == 0]
numb[numb % 2 != 0]
# Out:
# array([  5,  77, 399])

# %%
numb = np.array ([26, 14, 5, 77, 399])
np.where(numb % 2 == 0, 'True', 'False')
# Out:
# array(['True', 'True', 'False', 'False', 'False'], dtype='<U5')

# %%
np.random.seed(20)
print(np.random.seed(20))
# Out:
# None

# %%
# a = np.array([9,8,7,6])
a = np.array([8,6,7,9])
b = np.array([1,2,3,4,5])
c = np.array([3,3,3])
print(np.argmax(a))
np.argmin(b)
# Out:
# 3
# 0

# %%
np.argsort(a)
# Out:
# array([1, 2, 0, 3])

# %%
np.argsort(c)
# Out:
# array([0, 1, 2])

# %%
a = np.array([1,2,3,4])
print(np.quantile(a, 1))
print(np.quantile(a, 0))
print(np.quantile(a, 0.5))
# quantile value q to be between 0 and 1,
# Out:
# 4
# 1
# 2.5
